# %%
import pandas as pd

# %%
dados = pd.read_csv('fifa/basic_info.csv')

# %%
dados
# Out:
#        Unnamed: 0      ID                      Name  Age     Nationality  \
# 0               0  236988             Eddie Nketiah   22         England
# 1               1  225863          Olivier Boscagli   23          France
# 2               2  241721  Rafael da Conceição Leão   22        Portugal
# 3               3  224371              Jarrod Bowen   24         England
# 4               4  200104             Heung Min Son   28  Korea Republic
# ...           ...     ...                       ...  ...             ...
# 19820       20036  245534             Carl Spellman   18         England
# 19821       20037  245535         Abdulkadir Parmak   26          Turkey
# 19822       20038  245536             Andrea Errico   19           Italy
# 19823       20039  245540           Stratos Svarnas   23          Greece
# 19824       20097  259356        Carney Chukwuemeka   17         England
#
#        Overall  Potential                 Club              Contract   Value  \
# ...

# %%
dados.head(5)
# Out:
#    Unnamed: 0      ID                      Name  Age     Nationality  Overall  \
# 0           0  236988             Eddie Nketiah   22         England       72
# 1           1  225863          Olivier Boscagli   23          France       77
# 2           2  241721  Rafael da Conceição Leão   22        Portugal       82
# 3           3  224371              Jarrod Bowen   24         England       79
# 4           4  200104             Heung Min Son   28  Korea Republic       89
#
#    Potential               Club     Contract   Value   Wage  Total stat
# 0         79            Arsenal  2016 ~ 2022   €4.8M   €45K        1698
# 1         82                PSV  2019 ~ 2025  €14.5M   €15K        1961
# 2         90           AC Milan  2019 ~ 2024  €68.5M   €52K        1959
# 3         82    West Ham United  2020 ~ 2025    €24M   €63K        1966
# 4         89  Tottenham Hotspur  2015 ~ 2025   €104M  €240K        2141

# %%
dados.tail(8)
# Out:
#        Unnamed: 0      ID                Name  Age Nationality  Overall  \
# 19817       20033  245530      Lucas Calderón   22   Argentina       58
# 19818       20034  245531          Ryan Stirk   20       Wales       62
# 19819       20035  245533          Jay Devine   18     England       50
# 19820       20036  245534       Carl Spellman   18     England       52
# 19821       20037  245535   Abdulkadir Parmak   26      Turkey       71
# 19822       20038  245536       Andrea Errico   19       Italy       57
# 19823       20039  245540     Stratos Svarnas   23      Greece       69
# 19824       20097  259356  Carney Chukwuemeka   17     England       64
#
#        Potential                         Club              Contract  Value  \
# 19817         67  Gimnasia y Esgrima La Plata           2018 ~ 2022  €450K
# 19818         70               Mansfield Town  Jun 30, 2022 On Loan  €825K
# 19819         62              Tranmere Rovers           2018 ~ 2021   €50K
# ...

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Nationality', 'Overall',
#        'Potential', 'Club', 'Contract', 'Value', 'Wage', 'Total stat'],
#       dtype='object')

# %%
dados.index
# Out:
# RangeIndex(start=0, stop=19825, step=1)

# %%
dados[['Name','Nationality','Wage']]
# Out:
#                            Name     Nationality   Wage
# 0                 Eddie Nketiah         England   €45K
# 1              Olivier Boscagli          France   €15K
# 2      Rafael da Conceição Leão        Portugal   €52K
# 3                  Jarrod Bowen         England   €63K
# 4                 Heung Min Son  Korea Republic  €240K
# ...                         ...             ...    ...
# 19820             Carl Spellman         England   €500
# 19821         Abdulkadir Parmak          Turkey   €15K
# 19822             Andrea Errico           Italy    €2K
# 19823           Stratos Svarnas          Greece   €500
# 19824        Carney Chukwuemeka         England    €2K
#
# [19825 rows x 3 columns]

# %%
dados.iloc[1]
# Out:
# Unnamed: 0                    1
# ID                       225863
# Name           Olivier Boscagli
# Age                          23
# Nationality              France
# Overall                      77
# Potential                    82
# Club                        PSV
# Contract            2019 ~ 2025
# Value                    €14.5M
# Wage                       €15K
# Total stat                 1961
# Name: 1, dtype: object

# %%
dados.iloc[2,2]
# Out:
# 'Rafael da Conceição Leão'

# %%
dados.loc[dados['Nationality'] == 'Brazil']
# Out:
#        Unnamed: 0      ID                              Name  Age Nationality  \
# 6               6  232580          Gabriel dos S. Magalhães   23      Brazil
# 14             14  231943            Richarlison de Andrade   24      Brazil
# 22             22  238794  Vinícius José de Oliveira Júnior   20      Brazil
# 33             33  255475         Antony Matheus dos Santos   21      Brazil
# 38             38  251566  Gabriel Teodoro Martinelli Silva   20      Brazil
# ...           ...     ...                               ...  ...         ...
# 19646       19856  245783    Paulo Vítor Fagundes dos Anjos   31      Brazil
# 19704       19916  245717          Lucas Rodrigues da Silva   20      Brazil
# 19723       19938  245564              Caio Vinicius Pirana   21      Brazil
# 19773       19989  245476          Giácomo Mello Corbellini   25      Brazil
# 19776       19992  245480           Dyjan Carlos de Azevedo   27      Brazil
#
# ...

# %%
dados.sort_values('Age', ascending = False)
# Out:
#        Unnamed: 0      ID                     Name  Age Nationality  Overall  \
# 1636         1657  254704          Kazuyoshi Miura   54       Japan       56
# 651           660    1179         Gianluigi Buffon   43       Italy       80
# 8190         8293    2702            Kevin Ellison   42     England       59
# 15540       15721  254196  Luis Fernando Fernández   42    Colombia       61
# 2254         2284  105846              Artur Boruc   41      Poland       67
# ...           ...     ...                      ...  ...         ...      ...
# 200           202  266032      Jamie Bynoe-Gittens   16     England       65
# 9159         9277  265630            Brad Williams   16     England       51
# 9144         9262  265597             Joseph Gbode   16     England       53
# 8700         8815  266895          Nicolo Tresoldi   16       Italy       55
# 9893        10023  263636            Denis Oncescu   15     Romania       50
#
# ...

# %%
dados['Total'] = dados['Overall'] + dados['Potential']
dados
# Out:
#        Unnamed: 0      ID                      Name  Age     Nationality  \
# 0               0  236988             Eddie Nketiah   22         England
# 1               1  225863          Olivier Boscagli   23          France
# 2               2  241721  Rafael da Conceição Leão   22        Portugal
# 3               3  224371              Jarrod Bowen   24         England
# 4               4  200104             Heung Min Son   28  Korea Republic
# ...           ...     ...                       ...  ...             ...
# 19820       20036  245534             Carl Spellman   18         England
# 19821       20037  245535         Abdulkadir Parmak   26          Turkey
# 19822       20038  245536             Andrea Errico   19           Italy
# 19823       20039  245540           Stratos Svarnas   23          Greece
# 19824       20097  259356        Carney Chukwuemeka   17         England
#
#        Overall  Potential                 Club              Contract   Value  \
# ...

# %%
dados = dados[['Name', 'Total']]
dados.sort_values('Total', ascending = False)
# Out:
#                      Name  Total
# 122         Kylian Mbappé    186
# 86     Robert Lewandowski    184
# 43           Lionel Messi    184
# 16          Karim Benzema    182
# 173         Mohamed Salah    182
# ...                   ...    ...
# 2286          Daryl Sydes     95
# 11637         Mark Wright     94
# 7761      Frédéric Schaub     94
# 14908      Yeong Geun Kim     93
# 7546         Kevin Hacker     93
#
# [19825 rows x 2 columns]

# %%
dados.to_csv('Dados1.csv', index = False)

# %%
dados = pd.read_csv('Dados.total.de.melhores.jogadores.csv')
dados
# Out:
#                            Name  Total
# 0                 Eddie Nketiah    151
# 1              Olivier Boscagli    159
# 2      Rafael da Conceição Leão    172
# 3                  Jarrod Bowen    161
# 4                 Heung Min Son    178
# ...                         ...    ...
# 19820             Carl Spellman    116
# 19821         Abdulkadir Parmak    145
# 19822             Andrea Errico    127
# 19823           Stratos Svarnas    143
# 19824        Carney Chukwuemeka    151
#
# [19825 rows x 2 columns]

# %%
dados.sort_values('Total', ascending = False)
# Out:
#                      Name  Total
# 122         Kylian Mbappé    186
# 86     Robert Lewandowski    184
# 43           Lionel Messi    184
# 16          Karim Benzema    182
# 173         Mohamed Salah    182
# ...                   ...    ...
# 2286          Daryl Sydes     95
# 11637         Mark Wright     94
# 7761      Frédéric Schaub     94
# 14908      Yeong Geun Kim     93
# 7546         Kevin Hacker     93
#
# [19825 rows x 2 columns]

# %%
dados = pd.read_csv('fifa/basic_info.csv')
dados
# Out:
#        Unnamed: 0      ID                      Name  Age     Nationality  \
# 0               0  236988             Eddie Nketiah   22         England
# 1               1  225863          Olivier Boscagli   23          France
# 2               2  241721  Rafael da Conceição Leão   22        Portugal
# 3               3  224371              Jarrod Bowen   24         England
# 4               4  200104             Heung Min Son   28  Korea Republic
# ...           ...     ...                       ...  ...             ...
# 19820       20036  245534             Carl Spellman   18         England
# 19821       20037  245535         Abdulkadir Parmak   26          Turkey
# 19822       20038  245536             Andrea Errico   19           Italy
# 19823       20039  245540           Stratos Svarnas   23          Greece
# 19824       20097  259356        Carney Chukwuemeka   17         England
#
#        Overall  Potential                 Club              Contract   Value  \
# ...

# %%
dados.to_csv('Dados.total.de.melhores.jogadores.txt', index = False, sep='\t')

# %%
dados.to_csv('Dados1.txt', index = False, sep='\t')
